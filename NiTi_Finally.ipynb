# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import GradientBoostingRegressor
import numpy as np
import pandas as pd
from math import sqrt
from sklearn.metrics import mean_absolute_error as mae
import pickle
from sklearn import metrics
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_predict
import matplotlib.pyplot as plt
#from neupy.algorithms import RBFKMeans
#from neupy.algorithms import GRNN
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score
from sklearn.svm import SVR
from sklearn import svm
from pyGRNN import GRNN
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn import linear_model
import seaborn as sn
import joblib
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
#from skopt import BayesSearchCV
import warnings
import heapq
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=DeprecationWarning)

# %%
RF_Y_train_standard_realscale= np.load('./model_data/RF_Y_train_standard_realscale_1.npy')
RF_Y_test_standard_realscale=np.load('./model_data/RF_Y_test_standard_realscale_1.npy')
RF_pred_Y_train_standard_realscale= np.load('./model_data/RF_pred_Y_train_standard_realscale_1.npy')
RF_pred_Y_test_standard_realscale=np.load('./model_data/RF_pred_Y_test_standard_realscale_1.npy')

# %%
KNN_Y_train_standard_realscale= np.load('./model_data/KNN_Y_train_standard_realscale.npy')
KNN_Y_test_standard_realscale=np.load('./model_data/KNN_Y_test_standard_realscale.npy')
KNN_pred_Y_train_standard_realscale= np.load('./model_data/KNN_pred_Y_train_standard_realscale.npy')
KNN_pred_Y_test_standard_realscale=np.load('./model_data/KNN_pred_Y_test_standard_realscale.npy')

# %%
GRNN_Y_train_standard_realscale= np.load('./model_data/GRNN_Y_train_standard_realscale.npy')
GRNN_Y_test_standard_realscale=np.load('./model_data/GRNN_Y_test_standard_realscale.npy')
GRNN_pred_Y_train_standard_realscale= np.load('./model_data/GRNN_pred_Y_train_standard_realscale.npy')
GRNN_pred_Y_test_standard_realscale=np.load('./model_data/GRNN_pred_Y_test_standard_realscale.npy')

# %%
KNN_Y_train_standard_realscale= np.load('./model_data/KNN_Y_train_standard_realscale.npy')
KNN_Y_test_standard_realscale=np.load('./model_data/KNN_Y_test_standard_realscale.npy')
KNN_pred_Y_train_standard_realscale= np.load('./model_data/KNN_pred_Y_train_standard_realscale.npy')
KNN_pred_Y_test_standard_realscale=np.load('./model_data/KNN_pred_Y_test_standard_realscale.npy')

# %%
SVM_Y_train_standard_realscale= np.load('./model_data/SVM_Y_train_standard_realscale.npy')
SVM_Y_test_standard_realscale=np.load('./model_data/SVM_Y_test_standard_realscale.npy')
SVM_pred_Y_train_standard_realscale= np.load('./model_data/SVM_pred_Y_train_standard_realscale.npy')
SVM_pred_Y_test_standard_realscale=np.load('./model_data/SVM_pred_Y_test_standard_realscale.npy')

# %%
GBR_Y_train_standard_realscale= np.load('./model_data/GBR_Y_train_standard_realscale.npy')
GBR_Y_test_standard_realscale=np.load('./model_data/GBR_Y_test_standard_realscale.npy')
GBR_pred_Y_train_standard_realscale= np.load('./model_data/GBR_pred_Y_train_standard_realscale.npy')
GBR_pred_Y_test_standard_realscale=np.load('./model_data/GBR_pred_Y_test_standard_realscale.npy')

# %%
MLP_Y_train_standard_realscale= np.load('./model_data/MLP_Y_train_standard_realscale.npy')
MLP_Y_test_standard_realscale=np.load('./model_data/MLP_Y_test_standard_realscale.npy')
MLP_pred_Y_train_standard_realscale= np.load('./model_data/MLP_pred_Y_train_standard_realscale.npy')
MLP_pred_Y_test_standard_realscale=np.load('./model_data/MLP_pred_Y_test_standard_realscale.npy')

# %%
import matplotlib.font_manager as font_manager
hfont = {'fontname':'Times New Roman'}

x=([200,400])
y=([200,400])
x1=([200,400])
y1=([200,400])
fig=plt.figure( figsize=(9,6))

font = font_manager.FontProperties(family='Times New Roman')


ax=fig.add_subplot(231)
#plt.scatter(Y_standard_realscale,LR_pre_Y_standard_realscale, color="black",edgecolor="black",marker='o')
plt.scatter(KNN_Y_train_standard_realscale, KNN_pred_Y_train_standard_realscale, color="black",edgecolor="black",marker='o' ,label='Train')
plt.scatter(KNN_Y_test_standard_realscale, KNN_pred_Y_test_standard_realscale, color="none",edgecolor="red",marker='o',label='Test' )
#plt.scatter(SVMrbf_Y_train_standard_realscale,SVMrbf_pred_Y_train_standard_realscale, color="none",edgecolor="red",marker='o',label='Train' )
plt.title('KNN',size= 'large',**hfont)

plt.plot(x1,y1) 

#plt.text(0.77, 0.35, '$R^2$ train=%s'%(R2SVMrbf_train.round(2)), horizontalalignment='center',
 #        verticalalignment='center', transform=ax.transAxes,fontsize=12,**hfont)
#plt.text(0.77, 0.25, '$R^2$ test=%s'%(R2SVMrbf.round(2)), horizontalalignment='center', 
 #        verticalalignment='center', transform=ax.transAxes,fontsize=12,**hfont)
# plt.text(0.77, 0.05, 'RS=5009', horizontalalignment='center', verticalalignment='center', 
#          transform=ax.transAxes,fontsize=12,**hfont)
# S_LR = pd.DataFrame(LR_scores)
# print("mean CV {0}".format(S.CV.mean()))
# print("mean R2 {0}".format(S.R2.mean()))
# print("mean R2_train {0}".format(S.R2_train.mean()))
plt.text(0.77, 0.05, 'RMSE=6.11', horizontalalignment='center', verticalalignment='center', 
         transform=ax.transAxes,fontsize=12,**hfont)
# plt.text(0.77, 0.05, 'Iter=(%s,%s)'%(RF_BestFit_iter), horizontalalignment='center', verticalalignment='center', 
#          transform=ax.transAxes,fontsize=12,**hfont)
plt.text(0.77, 0.15, 'CV score=0.94',
         horizontalalignment='center', verticalalignment='center', transform=ax.transAxes,fontsize=12,**hfont)
plt.ylabel('Predicted Value',size= 'large',**hfont)
plt.xlabel('Actual Value',size= 'large',**hfont)
plt.legend(prop=font)


ax=fig.add_subplot(232)
#plt.scatter(KernelRidgePoly_Y_test_standard_realscale,KernelRidgePoly_pred_Y_test_standard_realscale, color="black",edgecolor="black",marker='o' ,label='Test')
#plt.scatter(KernelRidgePoly_Y_train_standard_realscale,KernelRidgePoly_pred_Y_train_standard_realscale, color="none",edgecolor="red",marker='o',label='Train' )
#plt.scatter(Y_standard_realscale,MLP_pre_Y_standard_realscale, color="black",edgecolor="black",marker='o')
plt.scatter(RF_Y_train_standard_realscale, RF_pred_Y_train_standard_realscale, color="black",edgecolor="black",marker='o' ,label='Train')
plt.scatter(RF_Y_test_standard_realscale, RF_pred_Y_test_standard_realscale, color="none",edgecolor="red",marker='o',label='Test' )
plt.title('RF',size= 'large',**hfont)
plt.plot(x1,y1) 

#plt.text(0.77, 0.35, '$R^2$ train=%s'%(R2KernelRidgePoly_train.round(2)), horizontalalignment='center',
 #        verticalalignment='center', transform=ax.transAxes,fontsize=12,**hfont)
#plt.text(0.77, 0.25, '$R^2$ test=%s'%(R2KernelRidgePoly.round(2)), horizontalalignment='center', 
 #        verticalalignment='center', transform=ax.transAxes,fontsize=12,**hfont)
#plt.text(0.77, 0.05, 'RS=5000', horizontalalignment='center', verticalalignment='center', 
#         transform=ax.transAxes,fontsize=12,**hfont)
# S_RF = pd.DataFrame(RF_scores)
# print("mean CV {0}".format(S.CV.mean()))
# print("mean R2 {0}".format(S.R2.mean()))
# print("mean R2_train {0}".format(S.R2_train.mean()))
plt.text(0.77, 0.05, 'RMSE=5.07', horizontalalignment='center', verticalalignment='center', 
         transform=ax.transAxes,fontsize=12,**hfont)
plt.text(0.77, 0.15, 'CV score=0.96',
         horizontalalignment='center', verticalalignment='center', transform=ax.transAxes,fontsize=12,**hfont)
plt.ylabel('Predicted Value',size= 'large',**hfont)
plt.xlabel('Actual Value',size= 'large',**hfont)
plt.legend(prop=font)


ax=fig.add_subplot(233)
#plt.scatter(KernelRidgePoly_Y_test_standard_realscale,KernelRidgePoly_pred_Y_test_standard_realscale, color="black",edgecolor="black",marker='o' ,label='Test')
#plt.scatter(KernelRidgePoly_Y_train_standard_realscale,KernelRidgePoly_pred_Y_train_standard_realscale, color="none",edgecolor="red",marker='o',label='Train' )
#plt.scatter(Y_standard_realscale,MLP_pre_Y_standard_realscale, color="black",edgecolor="black",marker='o')
plt.scatter(MLP_Y_train_standard_realscale, MLP_pred_Y_train_standard_realscale, color="black",edgecolor="black",marker='o' ,label='Train')
plt.scatter(MLP_Y_test_standard_realscale, MLP_pred_Y_test_standard_realscale, color="none",edgecolor="red",marker='o',label='Test' )
plt.title('MLP',size= 'large',**hfont)
plt.plot(x1,y1) 

#plt.text(0.77, 0.35, '$R^2$ train=%s'%(R2KernelRidgePoly_train.round(2)), horizontalalignment='center',
 #        verticalalignment='center', transform=ax.transAxes,fontsize=12,**hfont)
#plt.text(0.77, 0.25, '$R^2$ test=%s'%(R2KernelRidgePoly.round(2)), horizontalalignment='center', 
 #        verticalalignment='center', transform=ax.transAxes,fontsize=12,**hfont)
#plt.text(0.77, 0.05, 'RS=5000', horizontalalignment='center', verticalalignment='center', 
#         transform=ax.transAxes,fontsize=12,**hfont)

# S_MLP = pd.DataFrame(MLP_scores)
# print("mean CV {0}".format(S.CV.mean()))
# print("mean R2 {0}".format(S.R2.mean()))
# print("mean R2_train {0}".format(S.R2_train.mean()))
plt.text(0.77, 0.05, 'RMSE=11.74', horizontalalignment='center', verticalalignment='center', 
         transform=ax.transAxes,fontsize=12,**hfont)
plt.text(0.77, 0.15, 'CV score=0.78',
         horizontalalignment='center', verticalalignment='center', transform=ax.transAxes,fontsize=12,**hfont)


plt.xlabel('Actual Value',size= 'large',**hfont)
plt.ylabel('Predicted Value',size= 'large',**hfont)
plt.legend(prop=font)

#ax=fig.add_subplot(233)
#plt.scatter(KernelRidgelaplacian_Y_test_standard_realscale,KernelRidgelaplacian_pred_Y_test_standard_realscale, color="black",edgecolor="black",marker='o' ,label='Test')
#plt.scatter(KernelRidgelaplacian_Y_train_standard_realscale,KernelRidgelaplacian_pred_Y_train_standard_realscale, color="none",edgecolor="red",marker='o',label='Train' )
#plt.title('KRR (Laplacian)',size= 'large',**hfont)
#plt.plot(x1,y1) 

#plt.text(0.77, 0.35, '$R^2$ train=%s'%(R2KernelRidgelaplacian_train.round(2)), horizontalalignment='center',
 #        verticalalignment='center', transform=ax.transAxes,fontsize=12,**hfont)
#plt.text(0.77, 0.25, '$R^2 $test=%s'%(R2KernelRidgelaplacian.round(2)), horizontalalignment='center', 
 #        verticalalignment='center', transform=ax.transAxes,fontsize=12,**hfont)
#plt.text(0.77, 0.05, 'RS=5001', horizontalalignment='center', verticalalignment='center', 
 #        transform=ax.transAxes,fontsize=12,**hfont)
#plt.text(0.77, 0.15, 'CV score=%s'%(Cross_validation_Accuracy_KernelRidgelaplacian.round(2)),
 #        horizontalalignment='center', verticalalignment='center', transform=ax.transAxes,fontsize=12,**hfont)


ax=fig.add_subplot(234)
#plt.scatter(GBR_Y_test_standard_realscale,GBR_pred_Y_test_standard_realscale, color="black",edgecolor="black",marker='o' ,label='Test')
#plt.scatter(GBR_Y_train_standard_realscale,GBR_pred_Y_train_standard_realscale, color="none",edgecolor="red",marker='o',label='Train' )
#plt.scatter(Y_standard_realscale,GBR_pre_Y_standard_realscale, color="black",edgecolor="black",marker='o')
plt.scatter(GBR_Y_train_standard_realscale, GBR_pred_Y_train_standard_realscale, color="black",edgecolor="black",marker='o' ,label='Train')
plt.scatter(GBR_Y_test_standard_realscale, GBR_pred_Y_test_standard_realscale, color="none",edgecolor="red",marker='o',label='Test' )
plt.title('GBR',**hfont)
plt.plot(x,y) 

#plt.text(0.77, 0.35, '$R^2$ train=%s'%(R2Gradboost_train.round(2)), horizontalalignment='center',
 #        verticalalignment='center', transform=ax.transAxes,fontsize=12,**hfont)
#plt.text(0.77, 0.25, '$R^2$ test=%s'%(R2Gradboost.round(2)), horizontalalignment='center', 
 #        verticalalignment='center', transform=ax.transAxes,fontsize=12,**hfont)
#plt.text(0.77, 0.05, 'RS=5011', horizontalalignment='center', verticalalignment='center', 
#         transform=ax.transAxes,fontsize=12,**hfont)

# S_GBR = pd.DataFrame(GBR_scores)
# print("mean CV {0}".format(S.CV.mean()))
# print("mean R2 {0}".format(S.R2.mean()))
# print("mean R2_train {0}".format(S.R2_train.mean()))
plt.text(0.77, 0.05, 'RMSE=21.25', horizontalalignment='center', verticalalignment='center', 
         transform=ax.transAxes,fontsize=12,**hfont)
plt.text(0.77, 0.15, 'CV score=0.30',
         horizontalalignment='center', verticalalignment='center', transform=ax.transAxes,fontsize=12,**hfont)
plt.xlabel('Actual Value',size= 'large',**hfont)
plt.ylabel('Predicted Value',size= 'large',**hfont)
plt.legend(prop=font)


ax=fig.add_subplot(235)
#plt.scatter(MLP_Y_test_standard_realscale,MLP_pred_Y_test_standard_realscale, color="black",edgecolor="black",marker='o' ,label='Test')
#plt.scatter(MLP_Y_train_standard_realscale,MLP_pred_Y_train_standard_realscale, color="none",edgecolor="red",marker='o',label='Train' )
#plt.scatter(Y_standard_realscale,SVR_pre_Y_standard_realscale, color="black",edgecolor="black",marker='o')
plt.scatter(SVM_Y_train_standard_realscale, SVM_pred_Y_train_standard_realscale, color="black",edgecolor="black",marker='o' ,label='Train')
plt.scatter(SVM_Y_test_standard_realscale, SVM_pred_Y_test_standard_realscale, color="none",edgecolor="red",marker='o',label='Test' )
x2=([200,400])
y2=([200,400])
plt.plot(x2,y2) 
plt.title('SVM',**hfont)
#plt.text(0.77, 0.25, '$R^2$ test=%s'%(R2MLP.round(2)), horizontalalignment='center', 
 #       verticalalignment='center', transform=ax.transAxes,fontsize=12,**hfont)
#plt.text(0.77, 0.05, 'RS=5006', horizontalalignment='center', verticalalignment='center',
#         transform=ax.transAxes,fontsize=12,**hfont)

# S_SVM = pd.DataFrame(SVM_scores)
# print("mean CV {0}".format(S.CV.mean()))
# print("mean R2 {0}".format(S.R2.mean()))
# print("mean R2_train {0}".format(S.R2_train.mean()))
plt.text(0.77, 0.05, 'RMSE=23.97', horizontalalignment='center', verticalalignment='center', 
         transform=ax.transAxes,fontsize=12,**hfont)
plt.text(0.77, 0.15, 'CV score=0.13',
         horizontalalignment='center', verticalalignment='center', transform=ax.transAxes,fontsize=12,**hfont)
#plt.text(0.77, 0.35, '$R^2$ train=%s'%(R2MLP_train.round(2)), horizontalalignment='center', 
#        verticalalignment='center', transform=ax.transAxes,fontsize=12,**hfont)
plt.ylabel('Predicted Value',size= 'large',**hfont)
plt.xlabel('Actual Value',size= 'large',**hfont)
plt.legend(prop=font)



ax=fig.add_subplot(236)
#plt.scatter(Y_standard_realscale,GRNN_pre_Y_standard_realscale, color="black",edgecolor="black",marker='o' )
plt.scatter(GRNN_Y_train_standard_realscale, GRNN_pred_Y_train_standard_realscale, color="black",edgecolor="black",marker='o' ,label='Train')
plt.scatter(GRNN_Y_test_standard_realscale, GRNN_pred_Y_test_standard_realscale, color="none",edgecolor="red",marker='o',label='Test' )
#plt.scatter(GRNN_Y_test_standard_realscale,GRNN_pred_Y_test_standard_realscale, color="black",edgecolor="black",marker='o' ,label='Test')
#plt.scatter(GRNN_Y_train_standard_realscale,GRNN_pred_Y_train_standard_realscale, color="none",edgecolor="red",marker='o',label='Train' )
x3=([200,400])
y3=([200,400])
plt.plot(x3,y3) 
plt.title('GRNN',**hfont)
#plt.text(0.77, 0.25, '$R^2$ test=%s'%(R2GRNN.round(2)), horizontalalignment='center', verticalalignment='center',
 #        transform=ax.transAxes,fontsize=12,**hfont)
#plt.text(0.77, 0.05, 'RS=5048', horizontalalignment='center', verticalalignment='center', 
#         transform=ax.transAxes,fontsize=12,**hfont)

# S_GRNN = pd.DataFrame(GRNN_scores)
# # print("mean CV {0}".format(S.CV.mean()))
# # print("mean R2 {0}".format(S.R2.mean()))
# # print("mean R2_train {0}".format(S.R2_train.mean()))
plt.text(0.77, 0.05, 'RMSE=6.09', horizontalalignment='center', verticalalignment='center', 
         transform=ax.transAxes,fontsize=12,**hfont)
plt.text(0.77, 0.15, 'CV score=0.94',
         horizontalalignment='center', verticalalignment='center', transform=ax.transAxes,fontsize=12,**hfont)
#plt.text(0.77, 0.35, '$R^2$ train=%s'%(R2GRNN_train.round(2)), horizontalalignment='center',
 #        verticalalignment='center', transform=ax.transAxes ,fontsize=12,**hfont)


plt.ylabel('Predicted Value',size= 'large',**hfont)
plt.xlabel('Actual Value',size= 'large',**hfont)
plt.legend(prop=font)
plt.tight_layout(pad=0.5) 


plt.show()
#plt.savefig('Evaluation(2,2).png' , dpi=500)

# %%
# 加载模型
KNN = joblib.load('./model/KNN_model.pkl')
RF = joblib.load('./model/RF_model.pkl')
MLP = joblib.load('./model/MLP_model.pkl')
GBR = joblib.load('./model/GBR_model.pkl')
SVM = joblib.load('./model/SVM_model.pkl')
GRNN = joblib.load('./model/GRNN_model.pkl')

# %%
# 加载归一器
KNN_Xscaler = joblib.load('./model/KNN_Xscaler.pkl')
KNN_Yscaler = joblib.load('./model/KNN_Yscaler.pkl')
RF_Xscaler = joblib.load('./model/RF_Xscaler.pkl')
RF_Yscaler = joblib.load('./model/RF_Yscaler.pkl')
MLP_Xscaler = joblib.load('./model/MLP_Xscaler.pkl')
MLP_Yscaler = joblib.load('./model/MLP_Yscaler.pkl')
GBR_Xscaler = joblib.load('./model/GBR_Xscaler.pkl')
GBR_Yscaler = joblib.load('./model/GBR_Yscaler.pkl')
SVM_Xscaler = joblib.load('./model/SVM_Xscaler.pkl')
SVM_Yscaler = joblib.load('./model/SVM_Yscaler.pkl')
GRNN_Xscaler = joblib.load('./model/GRNN_Xscaler.pkl')
GRNN_Yscaler = joblib.load('./model/GRNN_Yscaler.pkl')

# %%
'''
Validation DataSets
'''
file_name = 'NiTi-3D打印工艺参数_Test_Phase.xlsx'
dataset = pd.read_excel(file_name, header=0)
#print(dataset)
x1 = dataset['激光功率P(W)'].values
x2 = dataset['扫描速度(mm/s)'].values
x3 = dataset['扫描间距h(um)'].values
x4 = dataset['层厚t(um)'].values
x5 = dataset['LED(J/mm)'].values
x6 = dataset['SED(J/mm2)'].values
x7 = dataset['VED(J/mm3)'].values
x8 = dataset['Ni'].values
x9 = dataset['Ti'].values
x10 = dataset['Dmin'].values
x11 = dataset['Dmax'].values
x12 = dataset['D10'].values
x13 = dataset['D50'].values
x14 = dataset['D90'].values
x15 = dataset['γ(原子半径)'].values
x16 = dataset['δ(原子半径差)'].values
x17 = dataset['ΔS(混合熵)'].values
x18 = dataset['ΔX(电负性)'].values
x19 = dataset['Tm(熔点)'].values
x20 = dataset['ΔH(混合焓)'].values
x21 = dataset['Ω(几何参数)'].values
x22 = dataset['٨(纯几何参数)'].values
x23 = dataset['VEC(价电子浓度)'].values

y1 = dataset['Ms'].values
y2 = dataset['Af'].values
X = np.column_stack((x1.reshape(-1, 1), 
                     x2.reshape(-1, 1), 
                     x3.reshape(-1, 1),
                     x4.reshape(-1, 1), 
                     x5.reshape(-1, 1),
                     x6.reshape(-1, 1),
                     x7.reshape(-1, 1),
                     x8.reshape(-1, 1),
                     x9.reshape(-1, 1),
                     x10.reshape(-1, 1),
                     x11.reshape(-1, 1),
                     x12.reshape(-1, 1),
                     x13.reshape(-1, 1),
                     x14.reshape(-1, 1),
                     x15.reshape(-1, 1),
                     x16.reshape(-1, 1),
                     x17.reshape(-1, 1),
                     x18.reshape(-1, 1),
                     x19.reshape(-1, 1),
                     x20.reshape(-1, 1),
                     x21.reshape(-1, 1),
                     x22.reshape(-1, 1),
                     x23.reshape(-1, 1)))

Y = np.column_stack((y1,y2))
Y = Y.round(0)

print(Y[:,0])
# Out:
# [341. 342. 341. 332. 300. 294. 343. 340. 331. 307. 300. 298.]

# %%
'''
Validation DataSets-GRNN
'''
x_standard = GRNN_Xscaler.transform(X)
y_standard = GRNN_Yscaler.transform(Y)
y_pre_standard = GRNN.predict(x_standard)
GRNN_y_pre_real = GRNN_Yscaler.inverse_transform(y_pre_standard)
GRNN_y_pre_real = GRNN_y_pre_real.round(0)
# print(Y)
# print(y_pre_real.round(0))

'''
Validation DataSets-KNN
'''
x_standard = KNN_Xscaler.transform(X)
y_standard = KNN_Yscaler.transform(Y)
y_pre_standard = KNN.predict(x_standard)
KNN_y_pre_real = KNN_Yscaler.inverse_transform(y_pre_standard)

'''
Validation DataSets-RF
'''
x_standard = RF_Xscaler.transform(X)
y_standard = RF_Yscaler.transform(Y)
y_pre_standard = RF.predict(x_standard)
RF_y_pre_real = RF_Yscaler.inverse_transform(y_pre_standard)

'''
Validation DataSets-MLP
'''
x_standard = MLP_Xscaler.transform(X)
y_standard = MLP_Yscaler.transform(Y)
y_pre_standard = MLP.predict(x_standard)
MLP_y_pre_real = MLP_Yscaler.inverse_transform(y_pre_standard)

'''
Validation DataSets-GBR
'''
x_standard = GBR_Xscaler.transform(X)
y_standard = GBR_Yscaler.transform(Y)
y_pre_standard = GBR.predict(x_standard)
GBR_y_pre_real = GBR_Yscaler.inverse_transform(y_pre_standard)

'''
Validation DataSets-SVM
'''
x_standard = SVM_Xscaler.transform(X)
y_standard = SVM_Yscaler.transform(Y)
y_pre_standard = SVM.predict(x_standard)
SVM_y_pre_real = SVM_Yscaler.inverse_transform(y_pre_standard)
print(Y[6:])
print(GRNN_y_pre_real)
# Out:
# [[341. 370.]
#  [342. 370.]
#  [341. 370.]
#  [332. 360.]
#  [300. 321.]
#  [294. 316.]
#  [343. 373.]
#  [340. 372.]
#  [331. 359.]
#  [307. 329.]
#  [300. 322.]
#  [298. 317.]]
# [[341. 373.]
#  [345. 373.]
#  [336. 367.]
#  [337. 363.]
#  [295. 321.]
#  [307. 343.]
#  [301. 328.]
#  [339. 369.]
#  [301. 330.]
#  [301. 325.]
#  [301. 325.]
#  [301. 328.]]
# d:\Conda\envs\ML\lib\site-packages\pyGRNN\GRNN.py:267: RuntimeWarning: invalid value encountered in true_divide
#   return np.nan_to_num((np.dot(self.y_.T, K) / psum))
# d:\Conda\envs\ML\lib\site-packages\pyGRNN\GRNN.py:267: RuntimeWarning: invalid value encountered in true_divide
#   return np.nan_to_num((np.dot(self.y_.T, K) / psum))

# %%
import matplotlib.font_manager as font_manager
hfont = {'fontname':'Times New Roman'}



fig=plt.figure( figsize=(9,6))

font = font_manager.FontProperties(family='Times New Roman')


ax=fig.add_subplot(231)
plt.scatter(x2,KNN_y_pre_real[:, 0],color="black",edgecolor="black",marker='+',label='Predicted' )
plt.scatter(x2,Y[:, 0], color="none",edgecolor="red",marker='o',label='Actuall' )
plt.title('K-Nearest Neighbor(KNN) ',**hfont)

#plt.text(0.05, 0.05, 'RMSE = 4.01', horizontalalignment='left', 
#         verticalalignment='center', transform=ax.transAxes,fontsize=12,**hfont)
#plt.text(0.05, 0.15, 'MAE = 3.38', horizontalalignment='left', 
#         verticalalignment='center', transform=ax.transAxes,fontsize=12,**hfont)
#plt.text(0.05, 0.25, '$R^2$ = -0.03', horizontalalignment='left', 
 #        verticalalignment='center', transform=ax.transAxes,fontsize=12,**hfont)

plt.ylabel('Ms(K)',size= 'large',**hfont)

plt.legend(prop=font)
plt.xlabel('Scanning Speed(mm/s) ',size= 'large',**hfont)

# plt.yticks(np.arange(0,15,2), fontsize=10)

ax=fig.add_subplot(232)
plt.scatter(x2,RF_y_pre_real[:, 0],color="black",edgecolor="black",marker='+',label='Predicted' )
plt.scatter(x2,Y[:, 0], color="none",edgecolor="red",marker='o',label='Actuall' )
plt.title('Random Forest(RF)',**hfont)

#plt.text(0.60, 0.48, 'RMSE = 2.44', horizontalalignment='left', 
#         verticalalignment='center', transform=ax.transAxes,fontsize=12,**hfont)
#plt.text(0.60, 0.58, 'MAE = 2.00', horizontalalignment='left', 
#         verticalalignment='center', transform=ax.transAxes,fontsize=12,**hfont)
#plt.text(0.60, 0.68, '$R^2$ = 0.63', horizontalalignment='left', 
 #        verticalalignment='center', transform=ax.transAxes,fontsize=12,**hfont)

plt.legend(prop=font)
plt.xlabel('Scanning Speed(mm/s) ',size= 'large',**hfont)

# plt.yticks(np.arange(0,15,2), fontsize=10)


ax=fig.add_subplot(233)
plt.scatter(x2,GBR_y_pre_real[:, 0],color="black",edgecolor="black",marker='+',label='Predicted' )
plt.scatter(x2,Y[:, 0], color="none",edgecolor="red",marker='o',label='Actuall' )
plt.title('Gradient Boosted Regression(GBR) ',**hfont)

#plt.text(0.2, 0.05, '$R^2 = 0.94$', horizontalalignment='center', verticalalignment='center', 
#         transform=ax.transAxes,fontsize=10,**hfont)
plt.xlabel('Scanning Speed(mm/s) ',size= 'large',**hfont)


plt.legend(prop=font)


# plt.yticks(np.arange(0,15,2), fontsize=10)

ax=fig.add_subplot(234)
plt.scatter(x2,MLP_y_pre_real[:, 0],color="black",edgecolor="black",marker='+',label='Predicted' )
plt.scatter(x2,Y[:, 0], color="none",edgecolor="red",marker='o',label='Actuall' )
plt.title('Multilayer Perceptron(MLP)',**hfont)
plt.ylabel('Ms(K)',size= 'large',**hfont)

#plt.text(0.2, 0.05, '$R^2 = 0.84$', horizontalalignment='center', verticalalignment='center',
 #        transform=ax.transAxes,fontsize=10,**hfont)

plt.legend(prop=font)
plt.xlabel('Scanning Speed(mm/s) ',size= 'large',**hfont)

# plt.yticks(np.arange(0,15,2), fontsize=10)

ax=fig.add_subplot(235)
plt.scatter(x2,GRNN_y_pre_real[:, 0],color="black",edgecolor="black",marker='+',label='Predicted' )
plt.scatter(x2,Y[:, 0], color="none",edgecolor="red",marker='o',label='Actuall' )
plt.title('Generalized Regression Neural Network(GRNN)',**hfont)
#plt.text(0.2, 0.05, '$R^2 = 0.93$', horizontalalignment='center', verticalalignment='center',
 #        transform=ax.transAxes,fontsize=10,**hfont)

plt.legend(prop=font)
plt.xlabel('Scanning Speed(mm/s) ',size= 'large',**hfont)
plt.tight_layout(pad=0.5) 
# plt.yticks(np.arange(0,15,2), fontsize=10)

ax=fig.add_subplot(236)
plt.scatter(x2,SVM_y_pre_real[:, 0],color="black",edgecolor="black",marker='+',label='Predicted' )
plt.scatter(x2,Y[:, 0], color="none",edgecolor="red",marker='o',label='Actuall' )
plt.title('Support Vector Machine(SVM)',**hfont)
#plt.text(0.2, 0.05, '$R^2 = 0.93$', horizontalalignment='center', verticalalignment='center',
 #        transform=ax.transAxes,fontsize=10,**hfont)

plt.legend(prop=font)
plt.xlabel('Scanning Speed(mm/s) ',size= 'large',**hfont)
plt.tight_layout(pad=0.5) 
# plt.yticks(np.arange(0,15,2), fontsize=10)

# plt.savefig('EvaluationTest.png' , dpi=500, facecolor='w', edgecolor='w',
#         orientation='portrait', format=None,
#         transparent=False, bbox_inches=None, pad_inches=0.1, metadata=None)
# Out:
# d:\Conda\envs\ML\lib\site-packages\ipykernel_launcher.py:12: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('+').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
#   if sys.path[0] == "":
# d:\Conda\envs\ML\lib\site-packages\ipykernel_launcher.py:31: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('+').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# d:\Conda\envs\ML\lib\site-packages\ipykernel_launcher.py:49: UserWarning: You passed a edgecolor/edgecolors ('black') for an unfilled marker ('+').  Matplotlib is ignoring the edgecolor in favor of the facecolor.  This behavior may change in the future.
# ...
